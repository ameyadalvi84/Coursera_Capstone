# %% [markdown]
# <h1><b>CAPSTONE PROJECT</b></h1>
# This notebook will be used for the Capstone Project.

# %%
import numpy as np
import pandas as pd

# %%
print("numpy version : ",np.__version__)
print("pandas version : ",pd.__version__)
# Out:
# numpy version :  1.16.5
# pandas version :  0.25.1

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!

# %%
# importing the necessary libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')

# %%
# importing the data
path = 'C:/Users/ameydalv/data/Data-Collisions.csv'
data = pd.read_csv(path)
data.head()
# Out:
# C:\Users\ameydalv\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# ...

# %% [markdown]
# ### Attribute Information
# |Attribute| Datatype-length|Description|
# | :---- | :----: | ---------: |
# |OBJECTID| ObjectID| ESRI unique identifier|
# |SHAPE| Geometry |ESRI geometry field |
# |INCKEY| Long | A unique key for the incident|
# |COLDETKEY| Long |Secondary key for the incident|
# |ADDRTYPE| Text, 12| Collision address type:<ol> Alley</ol><ol>Block</ol><ol>Intersection</ol>|
# |INTKEY | Double | Key that corresponds to the intersection associated with a collision |
# |LOCATION| Text, 255 | Description of the general location of the collision |
# |EXCEPTRSNCODE| Text, 10||
# |EXCEPTRSNDESC |Text, 300||
# |SEVERITYCODE | Text, 100| A code that corresponds to the severity of the collision: <ol>3—fatality</ol><ol>2b—serious injury</ol><ol>2—injury</ol><ol>1—prop damage</ol><ol>0—unknown</ol>|
# |SEVERITYDESC| Text| A detailed description of the severity of the collision|
# |COLLISIONTYPE| Text, 300| Collision type|
# |PERSONCOUNT| Double| The total number of people involved in the collision|
# |PEDCOUNT| Double| The number of pedestrians involved in the collision. This is entered by the state.|
# |PEDCYLCOUNT| Double| The number of bicycles involved in the collision. This is entered by the state.|
# |VEHCOUNT| Double | The number of vehicles involved in the collision. This is entered by the state.|
# |INJURIES| Double | The number of total injuries in the collision. This is entered by the state.|
# |SERIOUSINJURIES | Double | The number of serious injuries in the collision. This is entered by the state.|
# |FATALITIES | Double |The number of fatalities in the collision. This is entered by the state.|
# |INCDATE | Date | The date of the incident.|
# |INCDTTM | Text, 30 | The date and time of the incident.|
# |JUNCTIONTYPE| Text, 300| Category of junction at which collision took place|
# |SDOT_COLCODE| Text, 10 | A code given to the collision by SDOT.|
# |SDOT_COLDESC| Text, 300| A description of the collision corresponding to the collision code.|
# |INATTENTIONIND| Text, 1 | Whether or not collision was due to inattention. (Y/N)|
# |UNDERINFL| Text, 10 | Whether or not a driver involved was under the influence of drugs or alcohol. |
# |WEATHER | Text, 300 | A description of the weather conditions during the time of the collision.|
# |ROADCOND | Text, 300 | The condition of the road during the collision.|
# |LIGHTCOND | Text, 300 | The light conditions during the collision.|
# |PEDROWNOTGRNT | Text, 1| Whether or not the pedestrian right of way was not granted. (Y/N)|
# |SDOTCOLNUM| Text, 10| A number given to the collision by SDOT.|
# |SPEEDING| Text, 1| Whether or not speeding was a factor in the collision. (Y/N)|
# |ST_COLCODE| Text, 10| A code provided by the state that describes the collision. For more information about these codes, please see the State Collision Code Dictionary.|
# |ST_COLDESC| Text, 300| A description that corresponds to the state’s coding designation.|
# |SEGLANEKEY| Long| A key for the lane segment in which the collision occurred.|
# |CROSSWALKKEY| Long| A key for the crosswalk at which the collision occurred.|
# |HITPARKEDCAR| Text, 1| Whether or not the collision involved hitting a parked car. (Y/N)|
#
# ### State Collision Code Dictionary
#
# |Code| Description |
# |:-----|------:|
# |0 | Vehicle Going Straight Hits Pedestrian|
# |1 | Vehicle Turning Right Hits Pedestrian|
# |2 | Vehicle Turning Left Hits Pedestrian|
# |3 | Vehicle Backing Hits Pedestrian|
# |4 | Vehicle Hits Pedestrian - All Other Actions|
# |5 | Vehicle Hits Pedestrian - Actions Not Stated|
# |10 | Entering At Angle |
# |11 | From Same Direction -Both Going Straight-Both Moving- Sideswipe|
# |12 | From Same Direction -Both Going Straight-One Stopped- Sideswipe|
# |13 | From Same Direction - Both Going Straight - Both Moving - Rear End |
# |14 | From Same Direction - Both Going Straight - One Stopped - Rear End |
# |15 | From Same Direction - One Left Turn - One Straight |
# |16 | From Same Direction - One Right Turn - One Straight|
# |19 | One Car Entering Parked Position |
# |20 | One Car Leaving Parked Position |
# |21 | One Car Entering Driveway Access |
# |22 | One Car Leaving Driveway Access |
# |23 | From Same Direction - All Others |
# |24 | From Opposite Direction - Both Moving - Head On|
# |25 | From Opposite Direction - One Stopped - Head On|
# |26 | From Opposite Direction - Both Going Straight - sideswipe|
# |27 | From Opposite Direction - Both Going Straight - One Stopped - sideswipe|
# |28 | From Opposite Direction - One Left Turn - One Straight|
# |29 | From Opposite Direction - One Left Turn - One Right Turn|
# |30 | From Opposite Direction - All Others|
# |31 | Not Stated|
# |32 | One Parked - One Moving|
# |40 | Train Struck Moving Vehicle |
# |41 | Train Struck Stopped or Stalled Vehicle|
# |42 | Vehicle Struck Moving Train|
# |43 | Vehicle Struck Stopped Train|
# |44 | Unicycle|
# |45 | Bicycle|
# |46 | Tricycle|
# |47 | Domestic Animal (horse, cow, sheep, etc)|
# |48 | Domestic Animal Other (Cat, Dog etc)|
# |49 | Non Domestic Animal (deer, bear, elk, etc)|
# |50 | Struck Fixed Object|
# |51 | Struck Other Object|
# |52 | Vehicle Overturned|
# |53 | Person Fell, Jumped, or was Pushed From Vehicle|
# |54 | Fire Started In Vehicle|
# |55 | Accidently Overcame By Carbon Monoxide Poison|
# |56 | Breakage Of Any Part Of the Vehicle Resulting In Injury or in Further Property Damage|
# |57 | All Other Non-Collisions |
# |60 | Vehicle Hits State Road or Construction Machinery |
# |61 | Vehicle Struck By State Road or Construction Machinery |
# |62 | Vehicle Hits County Road or Construction Machinery|
# |63 | Vehicle Struck By County Road or Construction Machinery |
# |64 | Vehicle Hits City Road or Construction Machinery |
# |65 | Vehicle Struck By City Road or Construction Machinery |
# |66 | Vehicle Hits Other Road or Construction Machinery |
# |67 | Vehicle Struck by Other Road or Construction Machinery |
# |71 | Same Direction - Both Turning Right - Both Moving - Sideswipe|
# |72 | Same Direction - Both Turning Right - One Stopped - Sideswipe|
# |73 | Same Direction - Both Turning Right - Both Moving - Rear End|
# |74 | Same Direction - Both Turning Right - One Stopped - Rear End |
# |81 | Same Direction - Both Turning Left - Both Moving - Sideswipe |
# |82 | Same Direction - Both Turning Left - One Stopped - Sideswipe |
# |83 | Same Direction - Both Turning Left - Both Moving - Rear End |
# |84 | Same Direction - Both Turning Left - One Stopped - Rear End |

# %% [markdown]
# ### Understanding the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 38 columns):
# SEVERITYCODE      194673 non-null int64
# X                 189339 non-null float64
# Y                 189339 non-null float64
# OBJECTID          194673 non-null int64
# INCKEY            194673 non-null int64
# COLDETKEY         194673 non-null int64
# REPORTNO          194673 non-null object
# STATUS            194673 non-null object
# ADDRTYPE          192747 non-null object
# INTKEY            65070 non-null float64
# LOCATION          191996 non-null object
# EXCEPTRSNCODE     84811 non-null object
# EXCEPTRSNDESC     5638 non-null object
# SEVERITYCODE.1    194673 non-null int64
# SEVERITYDESC      194673 non-null object
# COLLISIONTYPE     189769 non-null object
# PERSONCOUNT       194673 non-null int64
# PEDCOUNT          194673 non-null int64
# PEDCYLCOUNT       194673 non-null int64
# VEHCOUNT          194673 non-null int64
# ...

# %%
data.describe()
# Out:
#         SEVERITYCODE              X              Y       OBJECTID  \
# count  194673.000000  189339.000000  189339.000000  194673.000000
# mean        1.298901    -122.330518      47.619543  108479.364930
# std         0.457778       0.029976       0.056157   62649.722558
# min         1.000000    -122.419091      47.495573       1.000000
# 25%         1.000000    -122.348673      47.575956   54267.000000
# 50%         1.000000    -122.330224      47.615369  106912.000000
# 75%         2.000000    -122.311937      47.663664  162272.000000
# max         2.000000    -122.238949      47.734142  219547.000000
#
#               INCKEY      COLDETKEY         INTKEY  SEVERITYCODE.1  \
# count  194673.000000  194673.000000   65070.000000   194673.000000
# mean   141091.456350  141298.811381   37558.450576        1.298901
# std     86634.402737   86986.542110   51745.990273        0.457778
# min      1001.000000    1001.000000   23807.000000        1.000000
# ...

# %%
# do we have imbalance data set
plt.figure(figsize=(10,8))
plt.pie(df.groupby('SEVERITYCODE')['Count'].sum(),autopct='%1.1f%%',colors=['mediumseagreen','firebrick'],
        explode=(0,0.05),startangle=90,
       textprops={'fontsize':'14'},
       labels=df['SEVERITYCODE'].unique())
plt.show()

# %% [markdown]
# ### Conclusion
#
# We have an imbalanced data set. Approx. 70% of data is not related to sever accident and only 30% of data is related to sever accident

# %%
#sns.set_style('whitegrid')
#data1 = data[['ADDRTYPE','SEVERITYCODE']]#.groupby(['ADDRTYPE','SEVERITYCODE'])
df = pd.DataFrame(data.groupby(['ADDRTYPE','SEVERITYCODE'])['ADDRTYPE'].count())
df.rename(columns={'ADDRTYPE':'Count'}, inplace=True)
df.reset_index(inplace=True)
#df.head()
#print(df.columns)
plt.figure(figsize=(12,8))
g = sns.barplot(x='ADDRTYPE',y='Count',hue='SEVERITYCODE', data=df) #color=('firebrick','mediumseagreen'))
for p in g.patches:
    g.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black')
plt.xlabel('Collision Address')
plt.ylabel('Count')
#plt.xticks(rotation=90)
plt.title('Collision Count based on Address Type and Severity Code')
plt.show()

# %%
fig = plt.figure(figsize=(15,15))

ax1 = plt.subplot2grid((1,2),(0,0))
plt.pie(x=df[df['SEVERITYCODE']==2]['Count'],
        labels=df[df['SEVERITYCODE']==2]['ADDRTYPE'],
        autopct='%1.1f%%',colors=['mediumslateblue','firebrick','mediumseagreen'],
        textprops={'fontsize':'14'})
plt.title("Severity 2 Accidents based on Address type")

ax1 = plt.subplot2grid((1,2),(0,1))
plt.pie(x=df[df['ADDRTYPE']=='Block']['Count'],labels=df[df['ADDRTYPE']=='Block']['SEVERITYCODE'],autopct='%1.1f%%',colors=['mediumseagreen','firebrick'],
      textprops={'fontsize':'14'},explode=(0,0.05),startangle=90)
plt.title("Accidents for Address type - Block based on severity")
plt.show()

#ax1 = plt.subplot2grid((2,2),(1,0))
#plt.pie(x=df[df['ADDRTYPE']=='Intersection']['Count'],labels=df[df['ADDRTYPE']=='Intersection']['SEVERITYCODE'],autopct='%1.1f%%',colors=['green','red'],
#      textprops={'fontsize':'14'},explode=(0,0.05),startangle=90)
#plt.title("Accidents for Address type - Intersection")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (12,8))
plt.pie(x=df[df['ADDRTYPE']=='Intersection']['Count'],labels=df[df['ADDRTYPE']=='Intersection']['SEVERITYCODE'],autopct='%1.1f%%',colors=['mediumseagreen','firebrick'],
      textprops={'fontsize':'14'},explode=(0,0.02),startangle=90)
plt.title("Accidents for Address type - Intersection")
plt.show()

# %% [markdown]
# ### Conclusion
#
# <ol>Majority of accidents happen at address type - <b>Block</b>
# <li>Also if accident happens at address type there is <i>~25%</i> probability that it will be sever</li>
# </ol>
#
# <ol>Next address where accidents occur the most is at - <b>Intersection</b>
#     <li>There <i>42.8%</i> chance that an accident at Intersction will be sever</li>
# </ol>

# %% [markdown]
# Does driving under influence result in sever accident?
# <br>Does our data help to answer this question.</br>

# %%
data['UNDERINFL'].value_counts()
# Out:
# N    100274
# 0     80394
# Y      5126
# 1      3995
# Name: UNDERINFL, dtype: int64

# %% [markdown]
# The information in UNDERINFL column is not clear we have values like
# <br><b>N</b></br>
# <br><b>0</b></br>
# <br><b>Y</b></br>
# <br><b>1</b></br>
# <br>So we are not sure if <b>N</b> means **no** and **Y** means **yes**. Or **0** means **no** and **1** means **yes**.
# Hence concluding anything using this UNDRINFL column is not possible.</br>

# %% [markdown]
# Lets check if Weather data gives us any idea or clue realted to severity of accidents.

# %%
data['WEATHER'].value_counts()
# Out:
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64

# %%
data['WEATHER'].isnull().sum()
# Out:
# 5081

# %%
df_weather = pd.DataFrame(data[['WEATHER','SEVERITYCODE']].groupby(['WEATHER','SEVERITYCODE'])['WEATHER'].count())
df_weather.rename(columns={'WEATHER':'Count'}, inplace=True)
df_weather.reset_index(inplace=True)
df_weather.head(30)
# Out:
#                      WEATHER  SEVERITYCODE  Count
# 0          Blowing Sand/Dirt             1     41
# 1          Blowing Sand/Dirt             2     15
# 2                      Clear             1  75295
# 3                      Clear             2  35840
# 4             Fog/Smog/Smoke             1    382
# 5             Fog/Smog/Smoke             2    187
# 6                      Other             1    716
# 7                      Other             2    116
# 8                   Overcast             1  18969
# 9                   Overcast             2   8745
# 10             Partly Cloudy             1      2
# 11             Partly Cloudy             2      3
# 12                   Raining             1  21969
# 13                   Raining             2  11176
# 14          Severe Crosswind             1     18
# 15          Severe Crosswind             2      7
# 16  Sleet/Hail/Freezing Rain             1     85
# 17  Sleet/Hail/Freezing Rain             2     28
# ...

# %%
#sns.set_style("darkgrid")
sns.barplot(x='Count', y='WEATHER', hue='SEVERITYCODE', data=df_weather, palette='Set1')#sns.color_palette("YlOrRd") )
#plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.pie(x=df_weather.groupby(['WEATHER'])['Count'].sum(),labels=df_weather['WEATHER'].unique(),autopct='%1.1f%%',
       explode=(0,0.01,0,0,0.02,0,0.02,0,0,0,0.01),
       startangle=90,
       textprops={'fontsize':'14'})
#plt.legend(labels=df_weather['WEATHER'].unique(), loc='upper right')
plt.show()

# %% [markdown]
# ### Conclusion
#
# Based on Weather we can say that most of the accidents takes place on
# <ol>
#     <li><b>Clear Weather - 58%</b></li>
#     <li><b>When it is Raining - 17.5%</b></li>
#     <li><b>Overcast Conditions - 14.6%</b></li>
# </ol>

# %%
#df_weather.groupby(['WEATHER'])['Count'].sum()
df_weather[df_weather['SEVERITYCODE']==2]['Count']
# Out:
# 1        15
# 3     35840
# 5       187
# 7       116
# 9      8745
# 11        3
# 13    11176
# 15        7
# 17       28
# 19      171
# 21      816
# Name: Count, dtype: int64

# %% [markdown]
# ##### What about the Road Condition?

# %%
data['ROADCOND'].value_counts()
# Out:
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64

# %%
data['ROADCOND'].isnull().sum()
# Out:
# 5012

# %%
df_road = pd.DataFrame(data[['ROADCOND','SEVERITYCODE']].groupby(['ROADCOND','SEVERITYCODE'])['ROADCOND'].count())
df_road.rename(columns={'ROADCOND':'Count'}, inplace=True)
df_road.reset_index(inplace=True)
df_road.head(30)
# Out:
#           ROADCOND  SEVERITYCODE  Count
# 0              Dry             1  84446
# 1              Dry             2  40064
# 2              Ice             1    936
# 3              Ice             2    273
# 4              Oil             1     40
# 5              Oil             2     24
# 6            Other             1     89
# 7            Other             2     43
# 8    Sand/Mud/Dirt             1     52
# 9    Sand/Mud/Dirt             2     23
# 10      Snow/Slush             1    837
# 11      Snow/Slush             2    167
# 12  Standing Water             1     85
# 13  Standing Water             2     30
# 14         Unknown             1  14329
# 15         Unknown             2    749
# 16             Wet             1  31719
# 17             Wet             2  15755

# %%
sns.set(font_scale=1.2)
sns.barplot(x='Count',y='ROADCOND',data=df_road, hue='SEVERITYCODE',palette='Set2',)
plt.show()

# %%
df_sub_road = df_road[(df_road['ROADCOND']=='Dry') | (df_road['ROADCOND']=='Wet') | (df_road['ROADCOND']=='Unknown')]
#df_sub_road.head()
plt.figure(figsize=(8,6))
plt.pie(x = df_sub_road[df_sub_road['SEVERITYCODE']==2]['Count'],labels=df_sub_road['ROADCOND'].unique(),
       autopct='%1.1f%%',
       explode = (0,0.1,0.01),
       colors=['darkorange','firebrick','mediumseagreen'],
       textprops={'fontsize':'14'},
       startangle=90)
plt.show()

# %% [markdown]
# ### Conclusion
# <br>Majority of accidents takes place on **Dry** road conditions followed by **Wet** and **Unknown** road conditions. If we consider only these three road conditions we can see that - **Dry** and **Wet** Road Conditions constitue 98% of all the sever Road accidents.</br>
# <ol>
#     <li>70.8% of Severe accidents takes place on <b>Dry</b> road conditions.</li>
#     <li>27.9% of sever accidents occur on <b>Wet</b> road conditions.</li>
# </ol>

# %% [markdown]
# #### Need to check effect of following fields on Severitycode
#
# <ol>
# <li><i>LIGHTCOND</i></li>
# <li><i>SPEEDING</i></li>
# <li><i>SEGLANEKEY</i></li>
# <li><i>CROSSWALKKEY</i></li>
# <li><i>HITPARKEDCAR</i></li>
# </ol>

# %%
data['LIGHTCOND'].value_counts()
# Out:
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
data['LIGHTCOND'].isnull().sum()
# Out:
# 5170

# %%
df_light = pd.DataFrame(data[['LIGHTCOND','SEVERITYCODE']].groupby(['LIGHTCOND','SEVERITYCODE'])['LIGHTCOND'].count())
df_light.rename(columns={'LIGHTCOND':'Count'},inplace=True)
df_light.reset_index(inplace=True)
df_light.head(20)
# Out:
#                    LIGHTCOND  SEVERITYCODE  Count
# 0    Dark - No Street Lights             1   1203
# 1    Dark - No Street Lights             2    334
# 2   Dark - Street Lights Off             1    883
# 3   Dark - Street Lights Off             2    316
# 4    Dark - Street Lights On             1  34032
# 5    Dark - Street Lights On             2  14475
# 6    Dark - Unknown Lighting             1      7
# 7    Dark - Unknown Lighting             2      4
# 8                       Dawn             1   1678
# 9                       Dawn             2    824
# 10                  Daylight             1  77593
# 11                  Daylight             2  38544
# 12                      Dusk             1   3958
# 13                      Dusk             2   1944
# 14                     Other             1    183
# 15                     Other             2     52
# 16                   Unknown             1  12868
# 17                   Unknown             2    605

# %%
sns.set(font_scale=1.08)
sns.barplot(x='Count',y='LIGHTCOND',hue='SEVERITYCODE',data=df_light)
plt.show()

# %% [markdown]
# #### Conclusion
#
# Similar to Data fields that we ahve seen till now majority of accidents are taking place in only under cetain conditons. For Lighting Condtions majority of accidents are taking place in **Daylight** follwed by **Dark - Street Lights on**.
# <br>
# I was expecting that more sever accidents would take place when light conditions are bad or not favorable like - *Dark - No Street Lights* or *Dark Street Lights off*. But from data we do not find any strong eveidence suggesting the same.
# </br>

# %%
plt.pie(df_light[df_light['LIGHTCOND']=='Dark - No Street Lights']['Count'], labels = df_light['SEVERITYCODE'].unique(),
       autopct='%1.1f%%',
       colors = ['royalblue','darkorange'],
       startangle=40,
       explode=(0,0.1))
plt.show()

# %%
plt.pie(df_light[df_light['LIGHTCOND']=='Dark - Street Lights Off']['Count'], labels = df_light['SEVERITYCODE'].unique(),
       autopct='%1.1f%%',
       colors = ['royalblue','darkorange'],
       startangle=40,
       explode=(0,0.1))
plt.show()

# %%
plt.pie(df_light[df_light['LIGHTCOND']=='Daylight']['Count'], labels = df_light['SEVERITYCODE'].unique(),
       autopct='%1.1f%%',
       colors = ['royalblue','darkorange'],
       startangle=40,
       explode=(0,0.1))
plt.show()

# %% [markdown]
# ### Checking impact of Speeding

# %%
data['SPEEDING'].value_counts()
# Out:
# Y    9333
# Name: SPEEDING, dtype: int64

# %%
data['SPEEDING'].isnull().sum()
# Out:
# 185340

# %%
df_speed=pd.DataFrame(data[['SPEEDING','SEVERITYCODE']].groupby(['SPEEDING','SEVERITYCODE'])['SPEEDING'].count())
df_speed.rename(columns={'SPEEDING':'Count'}, inplace= True)
df_speed.reset_index(inplace=True)
df_speed.head(10)
# Out:
#   SPEEDING  SEVERITYCODE  Count
# 0        Y             1   5802
# 1        Y             2   3531

# %%
plt.pie(df_speed['Count'],labels=df_speed['SEVERITYCODE'], autopct="%1.1f%%", 
       colors=['royalblue','darkorange'],
       startangle=45,
       explode=(0,0.05),
       shadow=True)
plt.show()

# %% [markdown]
# #### Conclusion
# Based on the data (excluding the nulls for SPEEDING), it is observed that if an accident occurs due to speeding then there is **37.8%** probability that it will be sever.
# <br>We have got lot of null values in SPEEDING column. Hence we cannot conclude anything for the entire dataset using this column.</br>

# %%
data['SEGLANEKEY'].value_counts()
# Out:
# 0         191907
# 6532          19
# 6078          16
# 12162         15
# 10336         14
#            ...
# 35157          1
# 10817          1
# 15043          1
# 525169         1
# 16376          1
# Name: SEGLANEKEY, Length: 1955, dtype: int64

# %%
data['SEGLANEKEY'].isnull().sum()
# Out:
# 0

# %%
data['CROSSWALKKEY'].unique()
# Out:
# array([     0, 520838, 521466, ..., 523792, 650595, 523322], dtype=int64)

# %%
data['CROSSWALKKEY'].value_counts()
# Out:
# 0         190862
# 523609        17
# 520838        15
# 525567        13
# 521707        10
#            ...
# 521019         1
# 630862         1
# 25545          1
# 523322         1
# 27186          1
# Name: CROSSWALKKEY, Length: 2198, dtype: int64

# %%
data['CROSSWALKKEY'].isnull().sum()
# Out:
# 0

# %%
data['HITPARKEDCAR'].isnull().sum()
# Out:
# 0

# %%
data['HITPARKEDCAR'].value_counts()
# Out:
# N    187457
# Y      7216
# Name: HITPARKEDCAR, dtype: int64

# %%
df_hit = pd.DataFrame(data[['HITPARKEDCAR','SEVERITYCODE']].groupby(['HITPARKEDCAR','SEVERITYCODE'])['HITPARKEDCAR'].count())
df_hit.rename(columns={'HITPARKEDCAR':'Count'},inplace=True)
df_hit.reset_index(inplace=True)
df_hit.head(10)
# Out:
#   HITPARKEDCAR  SEVERITYCODE   Count
# 0            N             1  129717
# 1            N             2   57740
# 2            Y             1    6768
# 3            Y             2     448

# %%
ax = sns.barplot(x='Count',y='HITPARKEDCAR',hue='SEVERITYCODE',data=df_hit,
           palette='Set1')
#for p in ax.patches:
#    ax.annotate(df_hit['Count'],(p.get_height(), 
 #                  (p.get_y() + p.get_width() / 2., p.get_height()))) 
                   #ha = 'center', va = 'center', 
                   #xytext = (0, 9), 
                   #textcoords = 'offset points')
plt.show()

# %%
data['COLLISIONTYPE'].value_counts()
# Out:
# Parked Car    47987
# Angles        34674
# Rear Ended    34090
# Other         23703
# Sideswipe     18609
# Left Turn     13703
# Pedestrian     6608
# Cycles         5415
# Right Turn     2956
# Head On        2024
# Name: COLLISIONTYPE, dtype: int64

# %%
data['COLLISIONTYPE'].isnull().sum()
# Out:
# 4904

# %%
df_collision = pd.DataFrame(data[['COLLISIONTYPE','SEVERITYCODE']].groupby(['COLLISIONTYPE','SEVERITYCODE'])['COLLISIONTYPE'].count())
df_collision.rename(columns={'COLLISIONTYPE':'Count'},inplace=True)
df_collision.reset_index(inplace=True)
df_collision.head()
# Out:
#   COLLISIONTYPE  SEVERITYCODE  Count
# 0        Angles             1  21050
# 1        Angles             2  13624
# 2        Cycles             1    671
# 3        Cycles             2   4744
# 4       Head On             1   1152

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='COLLISIONTYPE',y='Count', hue='SEVERITYCODE',data=df_collision,
           palette='Set1')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black')
plt.xticks(rotation=90)    
plt.show()

# %%
data['PERSONCOUNT'].value_counts()
# Out:
# 2     114231
# 3      35553
# 4      14660
# 1      13154
# 5       6584
# 0       5544
# 6       2702
# 7       1131
# 8        533
# 9        216
# 10       128
# 11        56
# 12        33
# 13        21
# 14        19
# 15        11
# 17        11
# 16         8
# 44         6
# 18         6
# 20         6
# 25         6
# 19         5
# 26         4
# 22         4
# 27         3
# 28         3
# 29         3
# 47         3
# 32         3
# 34         3
# 37         3
# 23         2
# 21         2
# 24         2
# 30         2
# 36         2
# 57         1
# 31         1
# 35         1
# 39         1
# 41         1
# 43         1
# 48         1
# 53         1
# 54         1
# 81         1
# Name: PERSONCOUNT, dtype: int64

# %%
df_prsncnt = pd.DataFrame(data[['PERSONCOUNT','SEVERITYCODE']].groupby(['PERSONCOUNT','SEVERITYCODE'])['PERSONCOUNT'].count())
df_prsncnt
# Out:
#                           PERSONCOUNT
# PERSONCOUNT SEVERITYCODE
# 0           1                    3782
#             2                    1762
# 1           1                    9858
#             2                    3296
# 2           1                   86420
# ...                               ...
# 48          2                       1
# 53          1                       1
# 54          2                       1
# 57          1                       1
# 81          2                       1
#
# [79 rows x 1 columns]

# %%
data['VEHCOUNT'].value_counts()
# Out:
# 2     147650
# 1      25748
# 3      13010
# 0       5085
# 4       2426
# 5        529
# 6        146
# 7         46
# 8         15
# 9          9
# 11         6
# 10         2
# 12         1
# Name: VEHCOUNT, dtype: int64

# %%
df_vehicle= pd.DataFrame(data[['VEHCOUNT','SEVERITYCODE']].groupby(['VEHCOUNT','SEVERITYCODE'])['VEHCOUNT'].count())
df_vehicle.rename(columns={'VEHCOUNT':'Count'}, inplace=True)
df_vehicle.reset_index(inplace=True)
df_vehicle.head()
# Out:
#    VEHCOUNT  SEVERITYCODE   Count
# 0         0             1    3858
# 1         0             2    1227
# 2         1             1   11643
# 3         1             2   14105
# 4         2             1  111701

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='VEHCOUNT',y='Count',hue='SEVERITYCODE',data=df_vehicle,
           palette='Set1')
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.2, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black')
plt.xticks(rotation=90)    
plt.xlabel("No of Vehicles involved in the accident")
#plt.legend(labels = df_vehicle['SEVERITYCODE'].unique(),loc='upper right')
plt.show()

# %%
df_intermediate = data[['ADDRTYPE','COLLISIONTYPE','PERSONCOUNT','VEHCOUNT','WEATHER','ROADCOND','LIGHTCOND','SEVERITYCODE']]
df_intermediate.head(10)
# Out:
#        ADDRTYPE COLLISIONTYPE  PERSONCOUNT  VEHCOUNT   WEATHER ROADCOND  \
# 0  Intersection        Angles            2         2  Overcast      Wet
# 1         Block     Sideswipe            2         2   Raining      Wet
# 2         Block    Parked Car            4         3  Overcast      Dry
# 3         Block         Other            3         3     Clear      Dry
# 4  Intersection        Angles            2         2   Raining      Wet
# 5  Intersection        Angles            2         2     Clear      Dry
# 6  Intersection        Angles            2         2   Raining      Wet
# 7  Intersection        Cycles            3         1     Clear      Dry
# 8         Block    Parked Car            2         2     Clear      Dry
# 9  Intersection        Angles            2         2     Clear      Dry
#
#                  LIGHTCOND  SEVERITYCODE
# 0                 Daylight             2
# 1  Dark - Street Lights On             1
# 2                 Daylight             1
# ...

# %%
one_hot_columns = ['ADDRTYPE','COLLISIONTYPE','WEATHER','ROADCOND','LIGHTCOND']
df_intermediate.isnull().sum()
# Out:
# ADDRTYPE         1926
# COLLISIONTYPE    4904
# PERSONCOUNT         0
# VEHCOUNT            0
# WEATHER          5081
# ROADCOND         5012
# LIGHTCOND        5170
# SEVERITYCODE        0
# dtype: int64

# %%
df_intermediate.dropna(inplace=True)
df_intermediate.isnull().sum()
# Out:
# C:\Users\ameydalv\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# ADDRTYPE         0
# COLLISIONTYPE    0
# PERSONCOUNT      0
# VEHCOUNT         0
# WEATHER          0
# ROADCOND         0
# LIGHTCOND        0
# SEVERITYCODE     0
# dtype: int64

# %%
df_final=pd.get_dummies(df_intermediate, columns=one_hot_columns, drop_first=True)

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187504 entries, 0 to 194672
# Data columns (total 40 columns):
# PERSONCOUNT                           187504 non-null int64
# VEHCOUNT                              187504 non-null int64
# SEVERITYCODE                          187504 non-null int64
# ADDRTYPE_Block                        187504 non-null uint8
# ADDRTYPE_Intersection                 187504 non-null uint8
# COLLISIONTYPE_Cycles                  187504 non-null uint8
# COLLISIONTYPE_Head On                 187504 non-null uint8
# COLLISIONTYPE_Left Turn               187504 non-null uint8
# COLLISIONTYPE_Other                   187504 non-null uint8
# COLLISIONTYPE_Parked Car              187504 non-null uint8
# COLLISIONTYPE_Pedestrian              187504 non-null uint8
# COLLISIONTYPE_Rear Ended              187504 non-null uint8
# COLLISIONTYPE_Right Turn              187504 non-null uint8
# COLLISIONTYPE_Sideswipe               187504 non-null uint8
# ...

# %%
df_final.corr()
# Out:
#                                     PERSONCOUNT  VEHCOUNT  SEVERITYCODE  \
# PERSONCOUNT                            1.000000  0.400479      0.128368
# VEHCOUNT                               0.400479  1.000000     -0.081014
# SEVERITYCODE                           0.128368 -0.081014      1.000000
# ADDRTYPE_Block                        -0.060863  0.094486     -0.194986
# ADDRTYPE_Intersection                  0.064465 -0.090458      0.199092
# COLLISIONTYPE_Cycles                  -0.042292 -0.305339      0.214620
# COLLISIONTYPE_Head On                  0.020705  0.029271      0.029179
# COLLISIONTYPE_Left Turn                0.049671  0.040773      0.056126
# COLLISIONTYPE_Other                   -0.180873 -0.353875     -0.036636
# COLLISIONTYPE_Parked Car              -0.094683  0.184087     -0.308820
# COLLISIONTYPE_Pedestrian              -0.040252 -0.326174      0.247025
# COLLISIONTYPE_Rear Ended               0.134991  0.211535      0.130250
# ...
